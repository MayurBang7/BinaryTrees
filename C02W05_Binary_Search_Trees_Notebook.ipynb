# %% [markdown]
# |                                     |                                      |
# | ---                                 | ---                                  |
# | <img src="http://drive.google.com/uc?export=view&id=1JzM1Jig5KAOCvU4tIf2t66B3gd1uy1rG" width=200px> |<img src="http://drive.google.com/uc?export=view&id=1kMibD1EUis_6bwFtFIOgvUg22zEdROns" width=200px>|
#
# Proprietary content. © Great Learning. All Rights Reserved. Unauthorized use or distribution prohibited.

# %% [markdown]
# # <font color='blue'> Table of Contents </font>
#
# ## <font color='blue'>Binary Search Tree
# * Introduction
# * BST implementation </font>
#
# ## <font color='blue'> E-commerce Product Management
# * Problem Statement
# * Approach
# * Implementation </font>
#
# ## <font color='blue'> Trees: Use cases </font>

# %% [markdown]
# # <font color='blue'> Introduction </font>
# In computer science, a binary search tree (BST), also called an ordered or sorted binary tree, is a rooted binary tree data structure whose internal nodes each store a key greater than all the keys in the node's left subtree and less than those in its right subtree. The time complexity of operations on the binary search tree is directly proportional to the height of the tree.
#
# Binary search trees allow binary search for fast lookup, addition, and removal of data items, and can be used to implement dynamic sets and lookup tables. Since the nodes in a BST are laid in such as way that each comparison skips about half of the remaining tree, the lookup performance is proportional to that of binary logarithm.
#
# The performance of a binary search tree is dependent on the order of insertion of the nodes into the tree; several variations of the binary search tree can be built with guaranteed worst-case performance. The basic operations include: search, traversal, insert and delete. BSTs with guaranteed worst-case complexities perform better than an unsorted array, which would require linear search time.
#
# The complexity analysis of BST shows that, on average, the insert, delete and search takes O(log n) for n nodes. In the worst case, they degrade to that of a singly linked list:O(n).

# %% [markdown]
# # <font color='blue'> Implementation </font>
#
# Binary search trees support three main operations: lookup (checking whether a key is present), insertion, and deletion of an element.
#
# The latter two possibly change the structural arrangement of the nodes in the tree, whereas the first one is a navigating and read-only operation. Other read-only operations are traversal, verification, etc
#
# ## <font color='blue'> Operations: Searching, Insertion, Height, Deletion </font>
#
# Searching and Insertion in a binary search tree for a specific key can be programmed recursively or iteratively.
#
# These operations begins by examining the root node.
#
#     If the tree is NULL , the key being searched for does not exist in the tree.
#     Otherwise, if the key equals that of the root, the search/insert is successful and the node is returned.
#
#     If the key is less than that of the root, the search proceeds by examining the left subtree. Similarly, if the key is greater than that of the root, the search proceeds by examining the right subtree.
#
#     This process is repeated until the key is found or the remaining subtree is NULL. If the searched key is not found after a NULL subtree is reached, then the key is not present in the tree.
#
#     If it is insertion then we create a Node and associate it on the left/right where the traversal operation terminated.
#
# For computing the height, the same recursive approach is taken, since the height of any given node is 1 plus the maximum height of the left or the right subtrees. In this regard a tree is said to be balanced if for all nodes the difference in height between the left and right subtree is maintained to be constant.
#
# A lazy deletion which is most commonly used approach utilizes the same strategy as search. Once we reach the node to be deleted then we set a flag on that node that it is deleted, and do not remove it from the tree. The advantage is that the balance of tree is maintained, avoid much of swaps/pointers/reference manipulations which can have drastic outcomes if not properly done. Also by "locality of reference" for data, we know that there is fair chances of deleted data to be reinserted. This also maintains the persistance of the data structure.
#
# ### <font color='blue'> Traversal </font>
#
# A BST can be traversed through three basic algorithms: inorder, preorder, and postorder tree walks
#
#     Inorder tree walk: Nodes from the left subtree get visited first, followed by the root node and right subtree.
#
#     Preorder tree walk: The root node gets visited first, followed by left and right subtrees.
#
#     Postorder tree walk: Nodes from the left subtree get visited first, followed by the right subtree, and finally the root.
#
# We are more interested in the Inorder travesal since it produced the output in a sorted manner for BST depending on the key data element.

# %%
class BinaryTreeNode:
    def __init__(self, data, keyindex):
        self.data = data
        self.keyindex = keyindex
        self.left = None
        self.right=None
        self.deleted = False
    
    def __str__(self):
        return "<{},({},{}),{},{},{},{}>".format(self.data[0],self.data[1][0],self.data[1][1],self.data[2],self.data[3],self.data[4],self.data[5])

def height(root):
    if root is None : return 0
    else : return max(height(root.left),height(root.right)) + 1
         
def insert(root,val, keyindex):
    if root is None:
        root = BinaryTreeNode(val,keyindex)
        return root
    if val[keyindex] == root.data[keyindex]:#element already exists in the tree
        root.deleted = False
        return root
    if val[keyindex] < root.data[keyindex]:
        root.left=insert(root.left,val,keyindex)
    else:
        root.right=insert(root.right,val,keyindex)
    return root

def inorder(root):
    if root==None : return
    inorder(root.left)
    if root.deleted==False : print(root)
    inorder(root.right)

def search(root,val,keyindex):
    if root==None : return None
    if root.data[keyindex] == val[keyindex] : return root
    elif root.data[keyindex] > val[keyindex] : return search(root.left,val,keyindex)
    elif root.data[keyindex] < val[keyindex] : return search(root.right,val,keyindex)

def delete(root,val,keyindex):#Lazy deletion to speed up response time
    if root==None : return None
    if root.data[keyindex] == val : root.deleted = True; return root
    elif root.data[keyindex] > val : return delete(root.left,val,keyindex)
    elif root.data[keyindex] < val : return delete(root.right,val,keyindex)

def isBalanced(root):
    if root == None : return True
    elif (height(root.left) - height(root.right)) == 0 : return True 
    elif abs(height(root.left) - height(root.right)) >= 1 : return False
    else : return (isBalanced(root.left) and isBalanced(root.right))

# %% [markdown]
# # <font color='blue'> E-commerce product management </font>
#
# ## <font color='blue'> Problem Statement </font>
#
# Let's consider the scenario of an e-commerce website. We want to organize the transactions and store them in a BST so that retrieval of data would happen quickly.
#
# The data on a node in above BST is made of following fields:
# 1. User ID
# 1. User Name: (First Name, Last Name) - tuple
# 1. Product ID
# 1. Product Name
# 1. Product Price
# 1. Purchase Timestamp
#
# We now construct 3 different BST using a different key each time:
# 1. User Name
# 1. Product Name
# 1. Purchase Timestamp
#
# Note that keyindex controls which field we choose to be the orderable entity in our BST.
#
# We explore the operations of insertion, deletion, inorder-traversal, height computation and balanced nature of these trees.
#
#
#
# ????

# %% [markdown]
# ### <font color='blue'> Operation Based on user name </font>

# %%
from datetime import datetime

keyidx = 1 #User name 
uname = BinaryTreeNode(["U10010",('Harry','Potter'),"P20001","Soap",55.6,datetime(2022,2,11,8,44)],keyidx)
uname = insert(uname,["U10002",('Pinky','Sharma'),"P20013","Calculator",1000.5,datetime(2022,2,12,7,55)],keyidx)
uname = insert(uname,["U10032",('Anish','Verma'),"P20007","Bag",300,datetime(2022,2,15,16,35)],keyidx)
uname = insert(uname,["U10001",('Gregory','Mendel'),"P20225","Table",707.4,datetime(2022,2,15,16,31)],keyidx)
uname = insert(uname,["U10022",('Zakhir','Hussain'),"P21014","Sitar",7000.6,datetime(2022,1,14,8,22)],keyidx)
uname = insert(uname,["U10012",('Albert','Einstien'),"P20018","Notebook",10.7,datetime(2021,2,12,7,25)],keyidx)
uname = insert(uname,["U13002",('Musk','Elon'),"P20717","Battery",2000.5,datetime(2022,2,1,17,22)],keyidx)
uname = insert(uname,["U10502",('Billy','Gates'),"P20812","iPhone",40000.5,datetime(2022,2,2,17,22)],keyidx)

# %%
inorder(uname)
print(height(uname))
print(isBalanced(uname))
# Out:
# <U10012,(Albert,Einstien),P20018,Notebook,10.7,2021-02-12 07:25:00>
# <U10032,(Anish,Verma),P20007,Bag,300,2022-02-15 16:35:00>
# <U10502,(Billy,Gates),P20812,iPhone,40000.5,2022-02-02 17:22:00>
# <U10001,(Gregory,Mendel),P20225,Table,707.4,2022-02-15 16:31:00>
# <U10010,(Harry,Potter),P20001,Soap,55.6,2022-02-11 08:44:00>
# <U13002,(Musk,Elon),P20717,Battery,2000.5,2022-02-01 17:22:00>
# <U10002,(Pinky,Sharma),P20013,Calculator,1000.5,2022-02-12 07:55:00>
# <U10022,(Zakhir,Hussain),P21014,Sitar,7000.6,2022-01-14 08:22:00>
# 4
# False

# %% [markdown]
# ### <font color='blue'> Operation Based on product name </font>

# %%
keyidx = 3 #Product name 
pname = BinaryTreeNode(["U10010",('Harry','Potter'),"P20001","Soap",55.6,datetime(2022,2,11,8,44)],keyidx)
pname = insert(pname,["U10002",('Pinky','Sharma'),"P20013","Calculator",1000.5,datetime(2022,2,12,7,55)],keyidx)
pname = insert(pname,["U10032",('Anish','Verma'),"P20007","Bag",300,datetime(2022,2,15,16,35)],keyidx)
pname = insert(pname,["U10001",('Gregory','Mendel'),"P20225","Table",707.4,datetime(2022,2,15,16,31)],keyidx)
pname = insert(pname,["U10022",('Zakhir','Hussain'),"P21014","Sitar",7000.6,datetime(2022,1,14,8,22)],keyidx)
pname = insert(pname,["U10012",('Albert','Einstien'),"P20018","Notebook",10.7,datetime(2021,2,12,7,25)],keyidx)
pname = insert(pname,["U13002",('Musk','Elon'),"P20717","Battery",2000.5,datetime(2022,2,1,17,22)],keyidx)
pname = insert(pname,["U10502",('Billy','Gates'),"P20812","iPhone",40000.5,datetime(2022,2,2,17,22)],keyidx)

# %%
inorder(pname)
delete(pname,"Sitar",keyidx)
print('After deletion:')
inorder(pname)
print('After insertion:')
pname = insert(pname,["U10022",('Zakhir','Hussain'),"P21014","Sitar",7000.6,datetime(2022,1,14,8,22)],keyidx)
inorder(pname)
# Out:
# <U10032,(Anish,Verma),P20007,Bag,300,2022-02-15 16:35:00>
# <U13002,(Musk,Elon),P20717,Battery,2000.5,2022-02-01 17:22:00>
# <U10002,(Pinky,Sharma),P20013,Calculator,1000.5,2022-02-12 07:55:00>
# <U10012,(Albert,Einstien),P20018,Notebook,10.7,2021-02-12 07:25:00>
# <U10022,(Zakhir,Hussain),P21014,Sitar,7000.6,2022-01-14 08:22:00>
# <U10010,(Harry,Potter),P20001,Soap,55.6,2022-02-11 08:44:00>
# <U10001,(Gregory,Mendel),P20225,Table,707.4,2022-02-15 16:31:00>
# <U10502,(Billy,Gates),P20812,iPhone,40000.5,2022-02-02 17:22:00>
# After deletion:
# <U10032,(Anish,Verma),P20007,Bag,300,2022-02-15 16:35:00>
# <U13002,(Musk,Elon),P20717,Battery,2000.5,2022-02-01 17:22:00>
# <U10002,(Pinky,Sharma),P20013,Calculator,1000.5,2022-02-12 07:55:00>
# <U10012,(Albert,Einstien),P20018,Notebook,10.7,2021-02-12 07:25:00>
# <U10010,(Harry,Potter),P20001,Soap,55.6,2022-02-11 08:44:00>
# <U10001,(Gregory,Mendel),P20225,Table,707.4,2022-02-15 16:31:00>
# ...

# %% [markdown]
# ### <font color='blue'> Operation Based on purchase date </font>

# %%
keyidx = 5 #Purchase date 
pdate = BinaryTreeNode(["U10010",('Harry','Potter'),"P20001","Soap",55.6,datetime(2022,2,11,8,44)],keyidx)
pdate = insert(pdate,["U10002",('Pinky','Sharma'),"P20013","Calculator",1000.5,datetime(2022,2,12,7,55)],keyidx)
pdate = insert(pdate,["U10032",('Anish','Verma'),"P20007","Bag",300,datetime(2022,2,15,16,35)],keyidx)
pdate = insert(pdate,["U10001",('Gregory','Mendel'),"P20225","Table",707.4,datetime(2022,2,15,16,31)],keyidx)
pdate = insert(pdate,["U10022",('Zakhir','Hussain'),"P21014","Sitar",7000.6,datetime(2022,1,14,8,22)],keyidx)
pdate = insert(pdate,["U10012",('Albert','Einstien'),"P20018","Notebook",10.7,datetime(2021,2,12,7,25)],keyidx)
pdate = insert(pdate,["U13002",('Musk','Elon'),"P20717","Battery",2000.5,datetime(2022,2,1,17,22)],keyidx)
pdate = insert(pdate,["U10502",('Billy','Gates'),"P20812","iPhone",40000.5,datetime(2022,2,2,17,22)],keyidx)

# %%
inorder(pdate)
height(pdate)
# Out:
# <U10012,(Albert,Einstien),P20018,Notebook,10.7,2021-02-12 07:25:00>
# <U10022,(Zakhir,Hussain),P21014,Sitar,7000.6,2022-01-14 08:22:00>
# <U13002,(Musk,Elon),P20717,Battery,2000.5,2022-02-01 17:22:00>
# <U10502,(Billy,Gates),P20812,iPhone,40000.5,2022-02-02 17:22:00>
# <U10010,(Harry,Potter),P20001,Soap,55.6,2022-02-11 08:44:00>
# <U10002,(Pinky,Sharma),P20013,Calculator,1000.5,2022-02-12 07:55:00>
# <U10001,(Gregory,Mendel),P20225,Table,707.4,2022-02-15 16:31:00>
# <U10032,(Anish,Verma),P20007,Bag,300,2022-02-15 16:35:00>
# 4

# %% [markdown]
# # <font color='blue'> Trees: use cases </font>
#
# # <font color='blue'> Decision Trees: Machine Learning </font>
#
# Decision trees are a common way of representing the decision-making process through a branching, tree-like structure. It’s often used to plan and plot business and operational decisions as a visual flowchart. The approach sees a branching of decisions which end at outcomes, resulting in a tree-like structure or visualisation.
#
# Decision trees are used as an approach in machine learning to structure the algorithm. A decision tree algorithm will be used to split dataset features through a cost function. The decision tree is grown before being optimised to remove branches that may use irrelevant features, a process called pruning. Parameters such as the depth of the decision tree can also be set, to lower the risk of overfitting or an overly complex tree.
#
# The majority of decision trees in machine learning will be used for classification problems, to categorise objects against learned features. The approach can also be used for regression problems, or as a method of predicting continuous outcomes from unseen data. The main benefits of using a decision tree in machine learning is its simplicity, as the decision-making process is easy to visualise and understand. However, decision trees in machine learning can become overly complex by generating very granular branches, so pruning of the tree structure is often a necessity.
#
#
# Decision trees are a way of modeling decisions and outcomes, mapping decisions in a branching structure. Decision trees are used to calculate the potential success of different series of decisions made to achieve a specific goal. The concept of a decision tree existed long before machine learning, as it can be used to manually model operational decisions like a flowchart. They are commonly taught and utilised in business, economics and operation management sectors as an approach to analysing organisational decision making.
#
# Decision trees are a form of predictive modeling, helping to map the different decisions or solutions to a given outcome. Decision tree are made up of different nodes. The root node is the start of the decision tree, which is usually the whole dataset within machine learning. Leaf nodes are the endpoint of a branch, or the final output of a series of decisions. The decision tree won’t branch any further from a leaf node. With decision trees in machine learning, the features of the data are internal nodes and the outcome is the leaf node.
#
# Decision trees are an approach used in supervised machine learning, a technique which uses labelled input and output datasets to train models. The approach is used mainly to solve classification problems, which is the use of a model to categorise or classify an object. Decision trees in machine learning are also used in regression problems, an approach used in predictive analytics to forecast outputs from unseen data.
#
# Decisions trees are popular in machine learning as they are a simple way of structuring a model. The tree-like structure also makes it simple to understand the decision-making process of the model
#
# ## <font color='blue'> Constructing Decision with Case Study </font>
#
# We can start from the root node which contains an attribute of Travel cost per km.
#
# * If the travel cost per km is expensive, the person uses a car.
# * If the travel cost per km is the standard price, the person uses a train.
# * If the travel cost is cheap, the decision tree needs to ask the next question about the gender of the person. If the person is a male, then he uses a bus.
# * If the gender is female, the decision tree needs to ask again how many cars she owns in her household.
# * If she has no car, she uses a bus,
# * Otherwise, she uses the train.
#
# ![Travel Decision.JPG](data:image/jpeg;base64,...)
#
#
# ## <font color='blue'> Decision Tree Example: Entertainment Decision </font>
#
#
# Imagine you only ever do four things at the weekend:
#
# 1. Go Shopping,
# 2. Watch A Movie,
# 3. Play Tennis Or
# 4. Just Stay In.
#
# What you do depends on three things:
#
# * The Weather (Windy, Rainy Or Sunny);
# * How Much Money You Have (Rich Or Poor) And
# * Whether Your Parents Are Visiting.
#
# The decision for Tree Classification
#
#     Rule 1: If My Parents Are Visiting, We’ll Go To The Cinema.
#     Rule 2: If They’re Not Visiting And It’s Sunny, Then I’ll Play Tennis, But
#     Rule 3: If It’s Windy, And I’m Rich, Then I’ll Go Shopping.
#     Rule 4: If They’re Not Visiting, It’s Windy And I’m Poor, Then I Will Go To The Cinema.
#     Rule 5: If They’re Not Visiting And It’s Rainy, Then I’ll Stay In.
#
# Now, you draw a flowchart which will enable you to read off your decision in the form of decision trees for the weekend decision choices would be as follows:
#
# ![Entertainment Decision.JPG](data:image/jpeg;base64,...)
